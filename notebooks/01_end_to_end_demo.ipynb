# %% [markdown]
# # End-to-End Netflix Recommendation Demo
#
# Run this notebook from the project root. It trains the demo recommender pipeline on the bundled sample dataset and writes metrics, figures, and recommendations.

# %%
# !pip install -r requirements.txt

# %%
# !python -m src.generate_sample_data
# !python -m src.train --data-dir data/sample --output-dir outputs/demo

# %%
import pandas as pd
metrics = pd.read_csv('outputs/demo/metrics.csv')
metrics

# %%
from IPython.display import Image, display
display(Image('outputs/demo/figures/rating_distribution.png'))
display(Image('outputs/demo/figures/top_movies.png'))

# %%
rec = pd.read_csv('outputs/demo/recommendations/item_item_cf_sample_recommendations.csv')
rec.head(10)

# %% [markdown]
# ## Run dashboard locally
#
# ```bash
# streamlit run app/streamlit_app.py
# ```
